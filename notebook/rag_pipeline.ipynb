# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")

# !git clone https://github.com/AniruddhaThorat/vehicle-spec-rag
# %cd vehicle-spec-rag

# !pip install -r requirements.txt

# %%
from src.pipeline import run_pipeline, batch_queries

# %%
pdf_path = "/content/vehicle-spec-rag/data/sample-service-manual 1.pdf"

query = "Torque specification for brake caliper bolts"

result = run_pipeline(pdf_path, query)
print(result)

# %% [markdown]
# **Batch:**

# %%
queries = [
    "Torque for brake caliper bolts",
    "Wheel nut torque",
    "Engine oil capacity",
    "Transmission fluid capacity"
]

results = batch_queries(pdf_path, queries)
print(results)
